# %%
import MORSM
from IPython.display import Image
# %matplotlib widget
from mpl_toolkits import mplot3d

# %% [markdown]
# # MOR-SM parameter settings

# %%
MORSM.params['Vr_1']=3000
MORSM.params['Vr_2']=3000
MORSM.params['EveMag']=6.0
MORSM.params
# Out:
# {'dh': 171,
#  'Xc': 175489.469137,
#  'Yc': 127683.51375307699,
#  'Zc': 10000,
#  'dip': 90,
#  'strike': 0,
#  'alpha': 0,
#  'Ga': 30000000000.0,
#  'Vr_2': 3000,
#  'Vr_1': 3000,
#  'aH': 0.0,
#  'bH': 0.2,
#  'aD': -0.3,
#  'bD': -0.4,
#  'sec_stage1': 10,
#  'EveMag': 6}

# %%
Image('melgar.png')

# %%
MORSM.createfig(first_y_ticks=1e18,seconed_y_ticks=2e17,x_ticks=2)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Create slip and time distribution

# %%
MORSM.Slip_and_time_distribution()

# %% [markdown]
# # Save files

# %%
MORSM.saveslipmodel_sw4('Simulation_name.txt')
MORSM.saveslipmodel_data('Slip_and_Time_contours.txt')

# %%
MORSM.Slip_and_time_distribution()
